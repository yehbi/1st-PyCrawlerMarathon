# %% [markdown]
# # YAHOO電影爬蟲練習
# ## 練習爬取電影放映資訊。必須逐步獲取電影的代號、放映地區、放映日期後，再送出查詢給伺服器。

# %%
import requests
import re
from bs4 import BeautifulSoup

# %% [markdown]
# ### 先搜尋全部的電影代號(ID)資訊

# %%
# 查看目前上映那些電影，並擷取出其ID資訊
url = 'https://movies.yahoo.com.tw/'
resp = requests.get(url)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
html = soup.find("select", attrs={'name':'movie_id'})
movie_item = html.find_all("option", attrs={'data-name':re.compile('.*')})
print(movie_item[0])
for p in movie_item:
    print("Movie: %s, ID: %s" % (p["data-name"], p["value"]))
# Out:
# <option data-name="復仇母親" value="10392">復仇母親</option>
# Movie: 復仇母親, ID: 10392
# Movie: 風暴過後, ID: 10387
# Movie: 南方車站的聚會, ID: 10380
# Movie: 祭旗, ID: 10373
# Movie: 唯你是愛, ID: 10370
# Movie: 屍控療法, ID: 10367
# Movie: 黑熊來了, ID: 10357
# Movie: 唐人街探案2, ID: 10353
# Movie: 黑計畫, ID: 10351
# Movie: HUMAN LOST人間失格, ID: 10348
# Movie: 假面騎士劇場版ZI-O Over Quartzer, ID: 10331
# Movie: 巴黎小情聖, ID: 10329
# Movie: 每個月來訪一次的月經醬, ID: 10324
# Movie: 8級警戒, ID: 10323
# Movie: 為你存在的每一天, ID: 10297
# Movie: 黑色聖誕節, ID: 10291
# Movie: 熱氣球飛行家, ID: 10257
# Movie: 大說謊家, ID: 10122
# Movie: 特約經紀公司, ID: 10364
# Movie: 一屍到底番外篇：好萊塢大作戰！, ID: 10352
# Movie: 花生醬獵鷹的願望, ID: 10340
# Movie: 女孩要革命, ID: 10339
# Movie: 我的靈魂是愛做的, ID: 10336
# Movie: 絕世情歌, ID: 10328
# Movie: 人間失格：太宰治與他的3個女人, ID: 10287
# Movie: 抓狂博物館, ID: 10279
# Movie: 呆萌特務, ID: 10264
# Movie: 去年聖誕節, ID: 10256
# Movie: 野蠻遊戲：全面晉級, ID: 10134
# Movie: 夕霧花園, ID: 10327
# Movie: 懸案密碼前傳：瓶中信, ID: 10254
# Movie: 布魯克林孤兒, ID: 10224
# Movie: 暴走曼哈頓, ID: 10044
# Movie: 鋒迴路轉, ID: 10258
# Movie: 賽道狂人, ID: 10097
# Movie: 麂皮：永不滿足, ID: 10358
# Movie: 82年生的金智英, ID: 10298
# Movie: 冰雪奇緣2, ID: 9597
# Movie: Hello World, ID: 10302
# Movie: 大餓, ID: 10296
# Movie: 我的情敵是冰箱, ID: 10286
# Movie: 萬萬沒想到, ID: 10281
# Movie: 為美好的世界獻上祝福！紅傳說, ID: 10226
# Movie: 山田孝之的痛苦與榮耀, ID: 10301
# Movie: 決戰中途島, ID: 10130
# Movie: 安眠醫生, ID: 10098
# Movie: 地久天長, ID: 9621
# Movie: 魔鬼終結者：黑暗宿命, ID: 10067
# Movie: 陽光普照, ID: 10240
# Movie: 狙擊獵殺：救援行動, ID: 10284
# Movie: 雙子殺手, ID: 10017
# Movie: 黑魔女2, ID: 10262
# Movie: 電影版 壞傢伙們, ID: 10249
# Movie: 藍波：最後一滴血, ID: 10205
# Movie: 屍樂園：髒比雙拼, ID: 10176
# Movie: 弒婚遊戲, ID: 10171
# Movie: 108悍將, ID: 10238
# Movie: 小丑, ID: 9949
# Movie: 校外打怪教學, ID: 10200
# Movie: 信用詐欺師JP, ID: 10190
# Movie: 無間行動, ID: 10155
# Movie: 星際救援, ID: 10227
# Movie: 返校, ID: 10109
# Movie: 唐頓莊園, ID: 10064
# Movie: 舞孃騙很大, ID: 10199
# Movie: 花椒之味, ID: 10158
# Movie: 好小男孩, ID: 9894
# Movie: 牠 第二章, ID: 10042
# Movie: 極限逃生, ID: 10174
# Movie: 你願意嫁給我老公嗎？, ID: 10141
# Movie: 下半場, ID: 9807
# Movie: 全面攻佔3：天使救援, ID: 10082
# Movie: 普羅米亞, ID: 10119
# Movie: 朵拉與失落的黃金城, ID: 9920
# Movie: 獅子王, ID: 9116
# Movie: 玩具總動員4, ID: 9924
# Movie: 毀滅者, ID: 9405
# Movie: 庫爾斯克號：深海救援, ID: 9134
# Movie: 厄夜追緝令, ID: 9589
# Movie: 苦兒流浪記, ID: 9538
# Movie: 活個精彩, ID: 9394
# Movie: 限時好友, ID: 9578
# Movie: 祝你忌日快樂, ID: 9568
# Movie: 艾莉塔：戰鬥天使, ID: 8553
# Movie: 馴龍高手3, ID: 8350
# Movie: 幸福綠皮書, ID: 9150
# Movie: 鬼太鼓座, ID: 8467
# Movie: 一首搖滾上月球, ID: 4887
# Movie: 錢不夠用2, ID: 3026

# %% [markdown]
# ### 指定你有興趣的電影其ID，然後查詢其放映地區資訊。

# %%
# 參考前一個步驟中擷取到的ID資訊，並指定ID
movie_id = 10392

# %%
url = 'https://movies.yahoo.com.tw/api/v1/areas_by_movie_theater'
payload = {'movie_id':str(movie_id)}

# 模擬一個header
headers = {
    'authority': 'movies.yahoo.com.tw',
    'method': 'GET',
    'path': '/api/v1/areas_by_movie_theater?movie_id=' + str(movie_id),
    'scheme': 'https',
    'accept': 'application/json, text/javascript, */*; q=0.01',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'cookie': 'rxx=9s3x2fws06.1g16irnc&v=1; _ga=GA1.3.2056742944.1551651301; GUC=AQEBAQFczFpdm0IfmwSB&s=AQAAACoo4N5D&g=XMsVBw; BX=4hkdk1decm57t&b=3&s=mr; _ga=GA1.4.2056742944.1551651301; nexagesuid=82843256dd234e8e91aa73f2062f8218; browsed_movie=; avi=eyJpdiI6Im1NeWFJRlVRWDR1endEcGRGUGJUbVE9PSIsInZhbHVlIjoickRpU3JuUytmcGl6cjF5OW0rNU9iZz09IiwibWFjIjoiY2VmY2NkNzZmM2NhNjY5YzlkOTcyNjE5OGEyMzU0NWYxOTdmMDRkMDY3OWNmMmZjOTMxYjc5MjI5N2Q5NGE5MiJ9; cmp=t=1559391030&j=0; _gid=GA1.4.779543841.1559391031; XSRF-TOKEN=%3D; m_s=; _gat=1; nexagesd=10',
    'dnt': '1',
    'mv-authorization': '21835b082e15b91a69b3851eec7b31b82ce82afb',
    'referer': 'https://movies.yahoo.com.tw/',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
}
    
resp = requests.get(url, params=payload, headers=headers)
print(resp.url)
print(resp.json())  # 若有需要，列印出json原始碼

# 這裡回傳的格式是JSON格式的資料，要解析JSON擷取資料
for p in resp.json():
    print('放映地區: {0}, 代號(area_id): {1}'.format(p['title'], p['area_id']))
# Out:
# https://movies.yahoo.com.tw/api/v1/areas_by_movie_theater?movie_id=10392
# [{'area_id': 28, 'title': '台北市', 'priority': 150, 'ts_update': 1547519309}, {'area_id': 8, 'title': '新北市', 'priority': 145, 'ts_update': 1547194527}, {'area_id': 16, 'title': '桃園', 'priority': 140, 'ts_update': 1547452573}, {'area_id': 2, 'title': '台中', 'priority': 125, 'ts_update': 1547507368}, {'area_id': 10, 'title': '台南', 'priority': 100, 'ts_update': 1547507403}, {'area_id': 17, 'title': '高雄', 'priority': 95, 'ts_update': 1547507403}]
# 放映地區: 台北市, 代號(area_id): 28
# 放映地區: 新北市, 代號(area_id): 8
# 放映地區: 桃園, 代號(area_id): 16
# 放映地區: 台中, 代號(area_id): 2
# 放映地區: 台南, 代號(area_id): 10
# 放映地區: 高雄, 代號(area_id): 17

# %% [markdown]
# ### 指定你想要觀看的放映地區，查詢有上映電影的場次日期

# %%
# 指定放映地區
area_id = 28

# %%
# 向網站發送請求
url = 'https://movies.yahoo.com.tw/movietime_result.html'
payload = {'movie_id':str(movie_id), 'area_id':str(area_id)}
resp = requests.get(url, params=payload)
resp.encoding = 'utf-8'
print(resp.url)
soup = BeautifulSoup(resp.text, 'lxml')
movie_date = soup.find_all("label", attrs={'for':re.compile("date_[\d]")})

# 列印播放日期
for date in movie_date:
    print(date)
    print("%s %s\n" % (date.p.string, date.h3.string))
# Out:
# https://movies.yahoo.com.tw/movietime_result.html?movie_id=10392&area_id=28
# <label class="picker_label" for="date_0">
# <p class="month">十二月</p>
# <h3 class="day">14</h3>
# <p class="week">今天</p>
# </label>
# 十二月 14
#
# <label class="picker_label" for="date_1">
# <p class="month">十二月</p>
# <h3 class="day">15</h3>
# <p class="week">明天</p>
# </label>
# 十二月 15
#
# <label class="picker_label" for="date_2">
# <p class="month">十二月</p>
# <h3 class="day">16</h3>
# <p class="week">禮拜一</p>
# </label>
# 十二月 16
#
# <label class="picker_label" for="date_3">
# <p class="month">十二月</p>
# <h3 class="day">17</h3>
# <p class="week">禮拜二</p>
# </label>
# 十二月 17
#
# <label class="picker_label" for="date_4">
# <p class="month">十二月</p>
# <h3 class="day">18</h3>
# <p class="week">禮拜三</p>
# </label>
# 十二月 18

# %% [markdown]
# ### 最後指定觀看的日期，查詢並列印出放映的電影院、放映類型(數位、3D、IMAX 3D...)、放映時間等資訊。

# %%
# 選定要觀看的日期
date = "2019-12-15"

# %%
# 向網站發送請求，獲取上映的電影院及時間資訊
url = "https://movies.yahoo.com.tw/ajax/pc/get_schedule_by_movie"
payload = {'movie_id':str(movie_id),
           'date':date,
           'area_id':str(area_id),
           'theater_id':'',
           'datetime':'',
           'movie_type_id':''}

resp = requests.get(url, params=payload)
print(resp.url)
#print(resp.json()['view'])  # 若有需要，列印出json原始碼

soup = BeautifulSoup(resp.json()['view'], 'lxml')
print(soup.prettify())
html = soup.find_all("ul", attrs={'data-theater_name':re.compile(".*")})
# Out:
# https://movies.yahoo.com.tw/ajax/pc/get_schedule_by_movie?movie_id=10392&date=2019-12-15&area_id=28&theater_id=&datetime=&movie_type_id=
# <html>
#  <body>
#   <div class="pc-movie-schedule-form">
#    <div class="area_timebox">
#     <div class="area_title">
#      台北市
#     </div>
#     <ul class="area_time _c jq_area_time" data-theater_name="台北in89豪華數位影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=36" data-theater_url="http://www.in89.com.tw/website_module.php?website_module_classify_sn=39" id="theater_id_36">
#      <li class="adds">
#       <a href="https://movies.yahoo.com.tw/theater_result.html/id=36">
#        台北in89豪華數位影城
#       </a>
#       <span>
#        02-23315077
#       </span>
#      </li>
#      <li class="taps">
#       <span class="tapR">
#        數位
#       </span>
#      </li>
#      <li class="time _c">
#       <div class="input_picker jq_input_picker">
#        <input class="gabtn" data-cinema="e9c365f27f4e11e494ae8b4ddf78b93a" data-date="1576339200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '復仇母親']" data-movie="e6c496a3aaf5458d965d4639a6479293" data-movie_date="12.15" data-movie_time="11:30" data-movie_title="復仇母親" data-movie_type="數位" data-session="1fccd6ed84a541659fe713452d83c585" data-time="1576380600" id="72586193" name="schedule_list" type="radio" value="2019-12-15 11:30:00"/>
#        <label class="select" for="72586193">
#         11:30
#        </label>
#        <input class="gabtn" data-cinema="e9c365f27f4e11e494ae8b4ddf78b93a" data-date="1576339200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '復仇母親']" data-movie="e6c496a3aaf5458d965d4639a6479293" data-movie_date="12.15" data-movie_time="17:50" data-movie_title="復仇母親" data-movie_type="數位" data-session="88341d8d4d4b4bbb91a1f59ae8146386" data-time="1576403400" id="72586194" name="schedule_list" type="radio" value="2019-12-15 17:50:00"/>
#        <label class="select" for="72586194">
#         17:50
#        </label>
#        <input class="gabtn" data-cinema="e9c365f27f4e11e494ae8b4ddf78b93a" data-date="1576339200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '復仇母親']" data-movie="e6c496a3aaf5458d965d4639a6479293" data-movie_date="12.15" data-movie_time="22:05" data-movie_title="復仇母親" data-movie_type="數位" data-session="feeeeb1a286445bb82cef53de4c59569" data-time="1576418700" id="72586195" name="schedule_list" type="radio" value="2019-12-15 22:05:00"/>
#        <label class="select" for="72586195">
#         22:05
#        </label>
#       </div>
#      </li>
#     </ul>
#     <ul class="area_time _c jq_area_time" data-theater_name="喜滿客絕色影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=42" data-theater_url="http://www.cinema7.com.tw/" id="theater_id_42">
#      <li class="adds">
#       <a href="https://movies.yahoo.com.tw/theater_result.html/id=42">
#        喜滿客絕色影城
#       </a>
#       <span>
#        02-23811339
#       </span>
#      </li>
#      <li class="taps">
#       <span class="tapR">
#        數位
#       </span>
#      </li>
#      <li class="time _c">
#       <div class="input_picker jq_input_picker">
#        <input class="gabtn" data-cinema="40288eb0050f542401050f55532606b5" data-date="1576339200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '復仇母親']" data-movie="65c23c9d14fc4a9daf2132ad9219d33f" data-movie_date="12.15" data-movie_time="09:50" data-movie_title="復仇母親" data-movie_type="數位" data-session="4336f1d4c45c493892dc11bc4a927686" data-time="1576374600" id="72586126" name="schedule_list" type="radio" value="2019-12-15 09:50:00"/>
#        <label class="select" for="72586126">
#         09:50
#        </label>
#        <input class="gabtn" data-cinema="40288eb0050f542401050f55532606b5" data-date="1576339200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '復仇母親']" data-movie="65c23c9d14fc4a9daf2132ad9219d33f" data-movie_date="12.15" data-movie_time="12:25" data-movie_title="復仇母親" data-movie_type="數位" data-session="bdc41d92773b4385b4512f8fe4dc5557" data-time="1576383900" id="72586142" name="schedule_list" type="radio" value="2019-12-15 12:25:00"/>
#        <label class="select" for="72586142">
#         12:25
#        </label>
#        <input class="gabtn" data-cinema="40288eb0050f542401050f55532606b5" data-date="1576339200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '復仇母親']" data-movie="65c23c9d14fc4a9daf2132ad9219d33f" data-movie_date="12.15" data-movie_time="16:25" data-movie_title="復仇母親" data-movie_type="數位" data-session="dce9170a9987485fb27b4296e8eb22b6" data-time="1576398300" id="72586143" name="schedule_list" type="radio" value="2019-12-15 16:25:00"/>
#        <label class="select" for="72586143">
#         16:25
#        </label>
#        <input class="gabtn" data-cinema="40288eb0050f542401050f55532606b5" data-date="1576339200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '復仇母親']" data-movie="65c23c9d14fc4a9daf2132ad9219d33f" data-movie_date="12.15" data-movie_time="20:40" data-movie_title="復仇母親" data-movie_type="數位" data-session="98bf3396cd694ed48e76de5799d77675" data-time="1576413600" id="72586144" name="schedule_list" type="radio" value="2019-12-15 20:40:00"/>
#        <label class="select" for="72586144">
#         20:40
#        </label>
#       </div>
#      </li>
#     </ul>
#     <ul class="area_time _c jq_area_time" data-theater_name="台北信義威秀影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=45" data-theater_url="http://www.vscinemas.com.tw/" id="theater_id_45">
#      <li class="adds">
#       <a href="https://movies.yahoo.com.tw/theater_result.html/id=45">
#        台北信義威秀影城
#       </a>
#       <span>
#        02-87805566
#       </span>
#      </li>
#      <li class="taps">
#       <span class="tapR">
#        數位
#       </span>
#      </li>
#      <li class="time _c">
#       <div class="input_picker jq_input_picker">
#        <input class="gabtn" data-cinema="40288eb0050f542401050f554e7e0674" data-date="1576339200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '復仇母親']" data-movie="75e4a44019294d609a223e6277ee4c2c" data-movie_date="12.15" data-movie_time="11:25" data-movie_title="復仇母親" data-movie_type="數位" data-session="3cedd110bae14f7b8fd395bd848ca5da" data-time="1576380300" id="72571960" name="schedule_list" type="radio" value="2019-12-15 11:25:00"/>
#        <label class="select" for="72571960">
#         11:25
#        </label>
#        <input class="gabtn" data-cinema="40288eb0050f542401050f554e7e0674" data-date="1576339200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '復仇母親']" data-movie="75e4a44019294d609a223e6277ee4c2c" data-movie_date="12.15" data-movie_time="20:40" data-movie_title="復仇母親" data-movie_type="數位" data-session="8f369435c03040e4801ba0bfe78ba46a" data-time="1576413600" id="72571961" name="schedule_list" type="radio" value="2019-12-15 20:40:00"/>
#        <label class="select" for="72571961">
#         20:40
#        </label>
#        <input class="gabtn" data-cinema="40288eb0050f542401050f554e7e0674" data-date="1576339200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '復仇母親']" data-movie="75e4a44019294d609a223e6277ee4c2c" data-movie_date="12.15" data-movie_time="23:15" data-movie_title="復仇母親" data-movie_type="數位" data-session="c2ca0c4d8a234134ba833dc5cfc7b010" data-time="1576422900" id="72571962" name="schedule_list" type="radio" value="2019-12-15 23:15:00"/>
#        <label class="select" for="72571962">
#         23:15
#        </label>
#       </div>
#      </li>
#     </ul>
#     <ul class="area_time _c jq_area_time" data-theater_name="喜樂時代影城南港店" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=186" data-theater_url="http://www.centuryasia.com.tw/default.aspx" id="theater_id_186">
#      <li class="adds">
#       <a href="https://movies.yahoo.com.tw/theater_result.html/id=186">
#        喜樂時代影城南港店
#       </a>
#       <span>
#        02-27888185
#       </span>
#      </li>
#      <li class="taps">
#       <span class="tapR">
#        數位
#       </span>
#      </li>
#      <li class="time _c">
#       <div class="input_picker jq_input_picker">
#        <input class="gabtn" data-cinema="40288eb0050f542401050f5681782dc5" data-date="1576339200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '復仇母親']" data-movie="d96760f7fd514773bf527cbbc0d65942" data-movie_date="12.15" data-movie_time="10:20" data-movie_title="復仇母親" data-movie_type="數位" data-session="eb94dc0578b94c0baf175849a3d29a62" data-time="1576376400" id="72576865" name="schedule_list" type="radio" value="2019-12-15 10:20:00"/>
#        <label class="select" for="72576865">
#         10:20
#        </label>
#        <input class="gabtn" data-cinema="40288eb0050f542401050f5681782dc5" data-date="1576339200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '復仇母親']" data-movie="d96760f7fd514773bf527cbbc0d65942" data-movie_date="12.15" data-movie_time="17:00" data-movie_title="復仇母親" data-movie_type="數位" data-session="86dc9f885e7b47b19e1ae50f4c793ddf" data-time="1576400400" id="72576866" name="schedule_list" type="radio" value="2019-12-15 17:00:00"/>
#        <label class="select" for="72576866">
#         17:00
#        </label>
#        <input class="gabtn" data-cinema="40288eb0050f542401050f5681782dc5" data-date="1576339200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '復仇母親']" data-movie="d96760f7fd514773bf527cbbc0d65942" data-movie_date="12.15" data-movie_time="22:30" data-movie_title="復仇母親" data-movie_type="數位" data-session="82adb7fa58ec4edda38d4ead3cc61eb9" data-time="1576420200" id="72576867" name="schedule_list" type="radio" value="2019-12-15 22:30:00"/>
#        <label class="select" for="72576867">
#         22:30
#        </label>
#       </div>
#      </li>
#     </ul>
#    </div>
#    <div class="booking_modal jq_booking_modal">
#     <div class="booking_modal_backdrop">
#     </div>
#     <!-- 時報訂票 ＆ 有官網訂票 新增 class => no_seats -->
#     <div class="booking_modal_content jq_booking_modal_content">
#      <form action="https://movies.yahoo.com.tw/ticket/ezding_ticket" id="form_schedule" method="get" target="_blank">
#       <div class="ezding_ticket_value">
#        <input name="movie_id" type="hidden" value=""/>
#        <input name="cinema_id" type="hidden" value=""/>
#        <input name="session_id" type="hidden" value=""/>
#        <input name="date" type="hidden" value=""/>
#        <input name="time" type="hidden" value=""/>
#        <input name="campaign_code" type="hidden" value="yahoopc"/>
#       </div>
#       <ul class="top_infos">
#        <li>
#         <p>
#          片名
#         </p>
#         <h3 id="top_infos_movie">
#         </h3>
#        </li>
#        <li>
#         <p>
#          影城
#         </p>
#         <h3 id="top_infos_theater">
#         </h3>
#        </li>
#        <li>
#         <p>
#          日期
#         </p>
#         <h3 id="top_infos_date">
#         </h3>
#        </li>
#        <li>
#         <p>
#          版本
#         </p>
#         <h3 id="top_infos_movie_type">
#         </h3>
#        </li>
#        <li>
#         <p>
#          時間
#         </p>
#         <h3 id="top_infos_time">
#         </h3>
#        </li>
#       </ul>
#       <div class="booking_seats">
#        <a class="theater_schedules gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_一般戲院_全部電影場次', '']" href="#">
#         全部電影場次
#        </a>
#        <a class="theater_url gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_一般戲院_官網訂票', '']" href="#" target="_blank">
#         官網訂票
#        </a>
#        <p class="no_theater_url" id="no_theater_url">
#         無提供官網訂票
#        </p>
#        <p class="booking_number" id="booking_number">
#         人數
#        </p>
#        <div class="booking_seat_group jq_booking_seat_group">
#         <input id="seat_1" name="tickets" type="radio" value="1"/>
#         <label for="seat_1">
#          1
#         </label>
#         <input checked="" id="seat_2" name="tickets" type="radio" value="2"/>
#         <label for="seat_2">
#          2
#         </label>
#         <input id="seat_3" name="tickets" type="radio" value="3"/>
#         <label for="seat_3">
#          3
#         </label>
#         <input id="seat_4" name="tickets" type="radio" value="4"/>
#         <label for="seat_4">
#          4
#         </label>
#         <input id="seat_5" name="tickets" type="radio" value="5"/>
#         <label for="seat_5">
#          5
#         </label>
#         <input id="seat_6" name="tickets" type="radio" value="6"/>
#         <label for="seat_6">
#          6
#         </label>
#        </div>
#        <button class="action_btn action_booking_btn jq_booking_btn gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_一般戲院_選位', '']" type="submit">
#         選位
#        </button>
#        <a class="action_btn action_link jq_booking_link gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_時報戲院_官網選位', '']" href="#" target="_blank">
#         官網訂票
#        </a>
#        <button class="action_btn close jq_close_booking_btn" type="button">
#         關閉
#        </button>
#       </div>
#      </form>
#      <!-- 無官網訂票區塊 -->
#      <div class="no_theater_section">
#       <p>
#        無提供官網訂票
#       </p>
#       <button class="action_btn close jq_close_booking_btn" type="button">
#        關閉
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>

# %%
gabtn=html[0].find_all(class_="gabtn")
for t in gabtn:
    print(t)
    print(t["value"])
    print("\n")
for h in html:
    print(h["data-theater_name"])
    print(h.a.string)
    print(h.find(class_="tapR").text)
    print("\n")
# Out:
# <input class="gabtn" data-cinema="e9c365f27f4e11e494ae8b4ddf78b93a" data-date="1576339200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '復仇母親']" data-movie="e6c496a3aaf5458d965d4639a6479293" data-movie_date="12.15" data-movie_time="11:30" data-movie_title="復仇母親" data-movie_type="數位" data-session="1fccd6ed84a541659fe713452d83c585" data-time="1576380600" id="72586193" name="schedule_list" type="radio" value="2019-12-15 11:30:00"/>
# 2019-12-15 11:30:00
#
#
# <input class="gabtn" data-cinema="e9c365f27f4e11e494ae8b4ddf78b93a" data-date="1576339200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '復仇母親']" data-movie="e6c496a3aaf5458d965d4639a6479293" data-movie_date="12.15" data-movie_time="17:50" data-movie_title="復仇母親" data-movie_type="數位" data-session="88341d8d4d4b4bbb91a1f59ae8146386" data-time="1576403400" id="72586194" name="schedule_list" type="radio" value="2019-12-15 17:50:00"/>
# 2019-12-15 17:50:00
#
#
# <input class="gabtn" data-cinema="e9c365f27f4e11e494ae8b4ddf78b93a" data-date="1576339200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '復仇母親']" data-movie="e6c496a3aaf5458d965d4639a6479293" data-movie_date="12.15" data-movie_time="22:05" data-movie_title="復仇母親" data-movie_type="數位" data-session="feeeeb1a286445bb82cef53de4c59569" data-time="1576418700" id="72586195" name="schedule_list" type="radio" value="2019-12-15 22:05:00"/>
# 2019-12-15 22:05:00
#
#
# 台北in89豪華數位影城
# 台北in89豪華數位影城
# 數位
#
#
# 喜滿客絕色影城
# 喜滿客絕色影城
# 數位
#
#
# 台北信義威秀影城
# 台北信義威秀影城
# 數位
#
#
# 喜樂時代影城南港店
# 喜樂時代影城南港店
# 數位

# %%
#試著從上一步驟回傳的電影院資料中，擷取電影院名稱、影片放映類型以及時間表
for h in html:
    print(h["data-theater_name"])
    print(h["data-theater_name"])
    #print(h.a.string)
    print(h.find(class_="tapR").text)
    h.find_all(class_="gabtn")
    for t in gabtn:
        #print(t)
        print(t["value"])
# Out:
# 台北in89豪華數位影城
# 數位
# 2019-12-15 11:30:00
# 2019-12-15 17:50:00
# 2019-12-15 22:05:00
# 喜滿客絕色影城
# 數位
# 2019-12-15 11:30:00
# 2019-12-15 17:50:00
# 2019-12-15 22:05:00
# 台北信義威秀影城
# 數位
# 2019-12-15 11:30:00
# 2019-12-15 17:50:00
# 2019-12-15 22:05:00
# 喜樂時代影城南港店
# 數位
# 2019-12-15 11:30:00
# 2019-12-15 17:50:00
# 2019-12-15 22:05:00
